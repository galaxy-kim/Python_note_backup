# %% [markdown]
# <a href="https://colab.research.google.com/github/galaxy-kim/Python_note_backup/blob/main/13_jan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##텍스트마이닝

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 31.4 MB/s eta 0:00:00
# ...

# %%
article_txt=open("/content/drive/MyDrive/Colab Notebooks/ubion_given_data/news.txt","rt",encoding="UTF-8").read()

# %%
article_txt
# Out:
# "임대소득세 대폭 줄이고…청년 지원은 확 늘린다 [새해 달라지는 것 23가지]③\n대학입학금 완전히 폐지·수능응시료 특별세액공제\n병장 기준 월 100만원으로 봉급 인상\n[이코노미스트 이용우·송재민·김서현 기자] 정부가 올해부터 주택임대소득 과세 고가주택 기준을 시가 9억원에서 12억원으로 인상하기로 했다. \n\n군인 장병들의 봉급은 병장 기준으로 월 100만원으로 인상하고 취업취약계층을 위한 국민취업지원제도도 확대된다.\n\n\n서울 남산에서 한 시민이 아파트 단지들을 바라보고 있다. [연합뉴스]\n\n대학입학금 '완전 폐지'…수능 응시료·대입 전형료 15% 세액공제\n\n2018년 국·공립대를 시작으로 단계적으로 없어지던 대학 입학금이 올해 완전히 폐지된다. 지난해까지만 해도 서울 일부 사립대에서 입학금을 걷어 왔지만 입학금의 산출 근거나 용도가 불분명하고 불투명하다는 지적이 계속 제기돼 폐지 요구가 많았다. 신입생들은 지난해까지 보통 19만~20만원의 입학금을 내야했다. 이에 정부에서 고등교육법을 개정하면서 입학금 징수 금지 조항을 신설하고 2023년부터 학부 신입생에게 입학금을 걷을 수 없게 했다.\n\n아울러 올해 1월 1일부터 기재부는 대학 진학을 위해 지출하는 비용인 대학입학전형료와 수능 응시료를 교육비특별세액공제에 적용한다. 현재는 본인이나 부양가족의 교육비로 지출하는 학비·입학금 등 교육비 지출액에 대해 15%의 세액공제를 받을 수 있는데, 앞으로는 대학입학 전형료와 수능 응시료도 받을 수 있게 됐다. \n\n주택임대소득 과세 고가주택 기준 인상\n\n올해부터 약 17억원짜리 고가 아파트를 보유한 1주택자의 종합부동산세와 임대소득세 등이 면제된다. 기획재정부는 올해부터 1주택자의 임대소득으로 과세되는 고가주택 기준을 종부세 기준과 동일하게 기준 시가 9억원에서 12억원으로 인상했다. \n\n올해 아파트 공시가격 현실화율 70% 적용 기준으로 공시가 12억원은 시가로 17억원 수준이다. 약 17억원짜리 아파트를 보유한 1주택자가 해당 아파
# ...

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
okt=Okt() #태그를 붙이는 함수
line=[]

line=okt.pos(article_txt) #품사를 붙여주는 함수
n_adj=[]
for word, tag in line:
    if tag in ["Noun","Adjective"]: #이런 태그가 붙은 경우
      n_adj.append(word) #이 리스트 안에 단어를 넣어라
print(n_adj)
# Out:
# ['임대', '소득세', '대폭', '줄', '청년', '지원', '확', '새해', '것', '가지', '대학입학', '금', '완전히', '폐지', '수능', '응시', '료', '특별', '세액', '공제', '병장', '기준', '월', '봉급', '인상', '이코노미스트', '이용우', '송재민', '김서현', '기자', '정부', '올해', '주택', '임대', '소득', '과세', '고가', '주택', '기준', '시가', '인상', '군인', '장병', '봉급', '병장', '기준', '월', '인상', '취업', '취약', '계층', '위', '국민', '취업', '제도', '확대', '서울', '남산', '시민', '아파트', '단지', '있다', '연합뉴스', '대학입학', '금', '완전', '폐지', '수능', '응시', '료', '대입', '전형', '료', '세액', '공제', '국', '공립', '시작', '단계', '대학', '입학', '금', '올해', '완전히', '폐지', '지난해', '해도', '서울', '일부', '사립대', '입학', '금', '입학', '금', '산출', '근거', '용도', '불분명', '불투명하다는', '지적', '계속', '제기', '폐지', '요구', '많았다', '신입생', '지난해', '보통', '입학', '금', '내야', '이', '정부', '고등', '교육법', '개정', '입학', '금', '징수', '금지', '조항', '신설', '학부', '신입생', '입학', '금', '수', '없게', '올해', '기재부', '대학', '진학', '위해', '지출', '비용', '대학입학', '전형', '료', '수능', '응시', '료', '교육비', '특별', '세액', '공제', '적용', '현재', '본인', '부양가족', '교육비', '지출', '학비', '입학', '금', '등', '교육비', '지출', '액', '대해', '의', '세액', '공제', '수', '있는데', '앞
# ...

# %%
#필요없는 단어 빼기
stop_words="세 등 금 수 료"
stop_words=set(stop_words.split(" "))
n_adj=[word for word in n_adj if not word in stop_words]

# %%
#몇번 등장했는지 카운팅
counts=Counter(n_adj)
tags=counts.most_common(20)
print(counts)
print(tags)
# Out:
# Counter({'취업': 15, '기준': 10, '올해': 10, '주택': 10, '인상': 9, '주민': 9, '수당': 8, '지원': 7, '입학': 7, '임대': 6, '병장': 6, '정부': 6, '봉급': 5, '소득': 5, '국민': 5, '아파트': 5, '등록증': 5, '발급': 5, '대학입학': 4, '폐지': 4, '수능': 4, '응시': 4, '세액': 4, '공제': 4, '월': 4, '고가': 4, '제도': 4, '지난해': 4, '종부세': 4, '만': 4, '센터': 4, '신청': 4, '소득세': 3, '과세': 3, '시가': 3, '취약': 3, '계층': 3, '위': 3, '확대': 3, '전형': 3, '지출': 3, '교육비': 3, '적용': 3, '액': 3, '자의': 3, '구직': 3, '촉진': 3, '어디': 3, '신규': 3, '방문': 3, '수령': 3, '제출': 3, '청년': 2, '것': 2, '완전히': 2, '특별': 2, '이용우': 2, '송재민': 2, '김서현': 2, '군인': 2, '장병': 2, '서울': 2, '있다': 2, '대학': 2, '신입생': 2, '이': 2, '신설': 2, '위해': 2, '본인': 2, '부양가족': 2, '앞': 2, '있게': 2, '약': 2, '보유': 2, '부담': 2, '발생': 2, '생계': 2, '이하': 2, '이상': 2, '중': 2, '증장': 2, '애인': 2, '잔': 2, '또': 2, '수급': 2, '경우': 2, '보상': 2, '국방부': 2, '계급': 2, '책정': 2, '월급': 2, '상병': 2, '일병': 2, '이병': 2, '생활': 2, '복무': 2, '서나': 2, '전국': 2, '관할': 2, '시': 2, '사진': 2, '전자': 2, '민원': 2, '창구': 2, '이용': 2, '대폭': 1, '줄': 1, '확': 1, '새해': 1, '가
# ...

# %%
from wordcloud import WordCloud

# %%
import numpy as np
from PIL import Image

# %%
font="/content/drive/MyDrive/Colab Notebooks/ubion_given_data/BlackHanSans-Regular.ttf"

mask = np.array(Image.open(
                r'/content/drive/MyDrive/Colab Notebooks/ubion_given_data/example.png'))

word_cloud=WordCloud(font_path=font,background_color="white",mask = mask,
                     max_font_size=300,colormap="Set2").generate_from_frequencies(dict(tags))
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.imshow(word_cloud)
plt.axis("off")
# Out:
# (-0.5, 1080.5, 549.5, -0.5)
